# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model= "gemma4:26b")

res = llm.invoke("Hello, I am Neeraj.")

res.content
# Out:
# "Hello Neeraj! It's nice to meet you. How can I help you today?"

# %%
res2 =llm.invoke("Are you Gemini? Who are you?")

print(res2.content)
# Out:
# I am a large language model, trained by Google.
